# %%
import opentxs
import pyopentxs
import runtests
runtests.restart_opentxs_notary()
pyopentxs.init()
# Out:
# removing lockfile /home/jweiss/.ot/client_data/ot.pid

# %%
from pyopentxs.nym import Nym
from pyopentxs import server
me = Nym().register()
other = Nym().register()
pyopentxs.otme.check_nym(server.first_active_id(), me._id, Nym().create()._id)
# Out:
# -----BEGIN SIGNED MESSAGE-----
# Hash: HASH256
#
# <?xml version="1.0"?>
#
# <notaryMessage
#  version="2.0"
#  dateSigned="1416840632">
#
# <registerNymResponse
#  requestNum="1"
#  success="true"
#  nymID="otxNKihVPd5YDmnSt6WfZBKgVBH3MiAedPR5"
#  notaryID="otxErn5TdNtmjrR3yPejbyW5RocFywhY7dzW">
#
# <nymfile>
# eNpVksmOolAARfd8RcWtSePjqWCiVhgshlcg8+AOEAGZKYaHX1/V3YtOL+89ydnc
# e3zHVfk2Jf1X3tSnFfVrs3o/E8d6qYRwCP8B8AOIt59aFk6rZsAayjNXv+8Coaqt
# Ye89bhxKXU6Cas4md93crc7EH40sWM3Yx8mZSLS2LOJhaV6sY+p3JvNJ1o3lbRfP
# uUhdFBnvFWlK+CG+GmIhLNzlMKcTBOpa/Wp3SU1oABxAN4EJ8F579bsPL09wN6pS
# sp0XwbvFGIr8s824vDFNJGZrVCjUuL7e2IiBfWcQH90rMmIbGjo2LshxeK5h5dYV
# 6QA+bU7GbLxgwS6Elslx3Qb+Aa0929lfb2FgJTR6EjqlW9pD6ccqNeSeLfx7bwtz
# q9TYFnW877UKi+uSHnaybJJlFJh93+FYesapSWYpRRLzk5t4ijM5o+NTLILtw+LF
# F7OJOjrfeiXdofATWhOVlmCotEOYbnYDzTPaI4iKfSiVBHSAkCwDJG2nodSFbWwm
# l5nUi1Rls/fouMwmio9cVA3tOPugOHR2NYCLBtzMm/WpJGimeSnCjDQ+RfNV244c
# QyGYpSiMG2h9FmUSIHiDNTNtdp5E9sHVH3VckqzkrjN7eyKO5H+r/s2/z3ImvgHI
# 57/7
# ...
